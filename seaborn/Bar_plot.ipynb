# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('../dengue_dataset.csv')

# %%
df.head(4)
# Out:
#    Id  Gender  Age       NS1       IgG       IgM  Platelet Count    WBC  \
# 0   1    Male   16  Positive  Negative  Negative          162000   9000
# 1   2  Female   25  Negative  Positive  Positive           90000  10000
# 2   3  Female   32  Negative  Negative  Negative          242000  11000
# 3   4    Male   42  Negative  Negative  Negative          326000  10000
#
#       Location   Outcome
# 0     Hasnabad  Positive
# 1        Ainta  Positive
# 2  Abdullahpur  Negative
# 3     Ruhitpur  Negative

# %%
df['Outcome']
# Out:
# 0       Positive
# 1       Positive
# 2       Negative
# 3       Negative
# 4       Positive
#           ...
# 1013    Positive
# 1014    Positive
# 1015    Negative
# 1016    Positive
# 1017    Negative
# Name: Outcome, Length: 1018, dtype: object

# %%
sns.barplot(x = df['Outcome'], y = df['WBC'], order = ['Negative','Positive'], hue = df.Gender, hue_order=['Female','Male'],
           errorbar = ('ci',1), palette = 'Accent', saturation = 0.9)
# Out:
# <Axes: xlabel='Outcome', ylabel='WBC'>
