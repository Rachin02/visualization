# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('../dengue_dataset.csv')

# %%
df.head(2)
# Out:
#    Id  Gender  Age       NS1       IgG       IgM  Platelet Count    WBC  \
# 0   1    Male   16  Positive  Negative  Negative          162000   9000
# 1   2  Female   25  Negative  Positive  Positive           90000  10000
#
#    Location   Outcome
# 0  Hasnabad  Positive
# 1     Ainta  Positive

# %%
sns.boxplot(df.WBC)
# Out:
# <Axes: ylabel='WBC'>

# %%
df = sns.load_dataset('tips')

# %%
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set(style= 'darkgrid')
sns.boxplot(x = df['day'], y = df.tip, showmeans = True, hue = df.sex, palette = 'Accent', linewidth = 2)
plt.show()
