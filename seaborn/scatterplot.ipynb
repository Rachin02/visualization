# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('../dengue_dataset.csv')

# %%
sns.scatterplot(x = df['Age'], y = df['WBC'], hue = df.Gender, style = df.Gender, size = df['Gender'], sizes = [100,70],
               palette = 'PuOr', markers = {'Male':'*','Female':'o'})
# Out:
# <Axes: xlabel='Age', ylabel='WBC'>
